# %%
# load libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data 
df = pd.read_csv(r"C:\Users\PC\Desktop\Masterarbeit\Code\NYT\articlesNYT_cleaned_flagged.csv")

# %%
# inspect the data
df.head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7349 entries, 0 to 7348
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   article_id      7349 non-null   int64
#  1   title           7038 non-null   object
#  2   sub_title       7188 non-null   object
#  3   corpus          7349 non-null   object
#  4   headline        7349 non-null   object
#  5   date            7349 non-null   object
#  6   section         7349 non-null   object
#  7   corpus_preview  7349 non-null   object
#  8   mentions_ai     7349 non-null   bool
# dtypes: bool(1), int64(1), object(7)
# memory usage: 466.6+ KB

# %%
# v isualize the data using seaborn
# Set the style of seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6)) 

# Create the countplot
ax = sns.countplot(data=df, x="section", hue="mentions_ai", palette=["blue", "red"])

# Add bar labels
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(
            p.get_x() + p.get_width() / 2.,  # x-position
            height + 1,                     # y-position 
            f'n={int(height)}',             # text label
            ha="center", va="bottom", fontsize=9
        )

# Final plot formatting
plt.title("AI-related Articles by Section in the WSJ (2024)")
plt.xlabel("Section")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="AI-related", loc="upper right", labels=["No", "Yes"])
plt.tight_layout()
plt.savefig(r"C:\Users\PC\Desktop\Masterarbeit\Code\NYT\NYT_articles_by_section.png", dpi=300)
plt.show()
