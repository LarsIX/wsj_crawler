# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time
from datetime import datetime, timedelta


ALLOWED_SECTIONS = {'business', 'opinion', 'world', 'us-news', 'tech', 'u.s.', 'finance', 'economy', 'politics', 'review-&-outlook', 'business-world'}


class ManagementDB:
    def __init__(self, db_name='articleswsj_2023.db'):
        self.conn = sqlite3.connect(db_name)
        self.c = self.conn.cursor()

    def insert_elements(self, elements):
        try:
            self.c.execute("""
                INSERT INTO articles_index 
                (headline, article_time, year, month, day, keyword, link, scraped_at, scanned_status) 
                VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
            """, (
                elements["headline"], elements["article_time"], elements["year"], elements["month"], elements["day"],
                elements["keyword"], elements["link"], elements["scraped_at"], elements["scanned_status"]
            ))
            self.conn.commit()
        except sqlite3.Error as e:
            print(f"❌ Database Insert Error: {e}")

    def exploration(self, link, day, month, year, page_num, values_or_not, count_articles):
        try:
            current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            self.c.execute("""
                INSERT INTO exploration 
                (link, day, month, year, page_num, checked_at, values_or_not, count_articles)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?)
            """, (link, day, month, year, page_num, current_time, values_or_not, count_articles))
            self.conn.commit()
        except sqlite3.Error as e:
            print(f"❌ Exploration Logging Error: {e}")

    def link_exists(self, link):
        self.c.execute("SELECT 1 FROM articles_index WHERE link = ?", (link,))
        return self.c.fetchone() is not None

    def closeDB(self):
        self.conn.close()

class WebScrap:
    def __init__(self):
        self.page_number = 1
        self.total_articles = 0

    def reset(self):
        self.page_number = 1
        self.total_articles = 0

    def get_elements_from_web(self, year, month, day, waiting_time):
        db = ManagementDB()
        while True:
            if self.page_number == 1:
                url = f'https://www.wsj.com/news/archive/{year}/{month:02}/{day:02}'
            else:
                url = f'https://www.wsj.com/news/archive/{year}/{month:02}/{day:02}?page={self.page_number}'

            print(f"\n🔎 Scraping URL: {url}")

            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers)

            if response.status_code != 200:
                print(f"❌ Failed to retrieve page. Status Code: {response.status_code}")
                break

            soup = BeautifulSoup(response.content, 'html.parser')
            ol_element = soup.find('ol', class_='WSJTheme--list-reset--3pR-r52l')
            article_elements = ol_element.find_all('article') if ol_element else []

            if not article_elements:
                db.exploration(url, day, month, year, self.page_number, 0, 0)
                print(f"✅ Finished scraping for {day}-{month}-{year}. Total articles: {self.total_articles}")
                break

            count_articles = 0

            for article in article_elements:
                headline_span = article.find('span', class_='WSJTheme--headlineText--He1ANr9C')
                a_tag = article.find('a')
                timestamp_p = article.find('p', class_='WSJTheme--timestamp--22sfkNDv')

                headline_text = headline_span.text if headline_span else "N/A"
                article_link = a_tag['href'] if a_tag else "N/A"
                article_time = timestamp_p.text if timestamp_p else "N/A"

                # Extract section directly from archive listing
                article_type_div = article.find('div', class_='WSJTheme--articleType--34Gt-vdG')
                section_div = article_type_div.find('div') if article_type_div else None
                article_section = section_div.text.strip().lower().replace(' ', '-') if section_div else "N/A"

                current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

                dict_elements = {
                    'headline': headline_text,
                    'article_time': article_time,
                    'year': year,
                    'month': month,
                    'day': day,
                    'keyword': article_section,
                    'link': article_link,
                    'scraped_at': current_time,
                    'scanned_status': 0,
                }

                if article_section in ALLOWED_SECTIONS and not db.link_exists(article_link):
                    db.insert_elements(dict_elements)
                    count_articles += 1

            db.exploration(url, day, month, year, self.page_number, 1, count_articles)
            self.total_articles += count_articles

            # Continue to next page regardless of article count
            self.page_number += 1
            time.sleep(waiting_time)

        db.closeDB()
        self.reset()

def get_dates(year):
    start_date = datetime(year, 1, 1)
    end_date = datetime(year, 12, 31)
    return [[current_date.day, current_date.month, current_date.year] 
            for current_date in (start_date + timedelta(days=n) for n in range((end_date - start_date).days + 1))]

def searching(target_year, waiting_time):
    dates = get_dates(target_year)
    scraper = WebScrap()

    for day, month, year in dates:
        print(f"\n📅 Starting scrape for date: {day}-{month}-{year}")
        scraper.get_elements_from_web(year, month, day, waiting_time)
        time.sleep(waiting_time)

if __name__ == '__main__':
    year_to_scrape = 2023     # Year to scrape
    waiting_time = 7          # Time to wait between requests (seconds)

    searching(year_to_scrape, waiting_time)
    print("\n🏁 Scraping completed successfully.")
# Out:
# 📅 Starting scrape for date: 1-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/01
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/01?page=2
# ✅ Finished scraping for 1-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 2-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/02
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/02?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/02?page=3
# ✅ Finished scraping for 2-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 3-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/03
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/03?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/03?page=3
# ✅ Finished scraping for 3-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 4-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/04
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/04?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/04?page=3
# ✅ Finished scraping for 4-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 5-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/05
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/05?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/05?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/05?page=4
# ✅ Finished scraping for 5-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 6-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/06
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/06?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/06?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/06?page=4
# ✅ Finished scraping for 6-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 7-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/07
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/07?page=2
# ✅ Finished scraping for 7-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 8-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/08
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/08?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/08?page=3
# ✅ Finished scraping for 8-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 9-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/09
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/09?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/09?page=3
# ✅ Finished scraping for 9-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 10-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/10
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/10?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/10?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/10?page=4
# ✅ Finished scraping for 10-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 11-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/11
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/11?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/11?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/11?page=4
# ✅ Finished scraping for 11-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 12-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/12
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/12?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/12?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/12?page=4
# ✅ Finished scraping for 12-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 13-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/13
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/13?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/13?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/13?page=4
# ✅ Finished scraping for 13-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 14-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/14
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/14?page=2
# ✅ Finished scraping for 14-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 15-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/15
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/15?page=2
# ✅ Finished scraping for 15-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 16-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/16
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/16?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/16?page=3
# ✅ Finished scraping for 16-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 17-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/17
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/17?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/17?page=3
# ✅ Finished scraping for 17-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 18-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/18
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/18?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/18?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/18?page=4
# ✅ Finished scraping for 18-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 19-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/19
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/19?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/19?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/19?page=4
# ✅ Finished scraping for 19-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 20-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/20
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/20?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/20?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/20?page=4
# ✅ Finished scraping for 20-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 21-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/21
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/21?page=2
# ✅ Finished scraping for 21-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 22-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/22
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/22?page=2
# ✅ Finished scraping for 22-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 23-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/23
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/23?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/23?page=3
# ✅ Finished scraping for 23-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 24-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/24
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/24?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/24?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/24?page=4
# ✅ Finished scraping for 24-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 25-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/25
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/25?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/25?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/25?page=4
# ✅ Finished scraping for 25-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 26-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/26
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/26?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/26?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/26?page=4
# ✅ Finished scraping for 26-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 27-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/27
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/27?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/27?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/27?page=4
# ✅ Finished scraping for 27-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 28-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/28
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/28?page=2
# ✅ Finished scraping for 28-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 29-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/29
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/29?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/29?page=3
# ✅ Finished scraping for 29-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 30-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/30
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/30?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/30?page=3
# ✅ Finished scraping for 30-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 31-1-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/31
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/31?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/31?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/01/31?page=4
# ✅ Finished scraping for 31-1-2023. Total articles: 0
#
# 📅 Starting scrape for date: 1-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/01
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/01?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/01?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/01?page=4
# ✅ Finished scraping for 1-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 2-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/02
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/02?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/02?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/02?page=4
# ✅ Finished scraping for 2-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 3-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/03
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/03?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/03?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/03?page=4
# ✅ Finished scraping for 3-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 4-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/04
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/04?page=2
# ✅ Finished scraping for 4-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 5-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/05
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/05?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/05?page=3
# ✅ Finished scraping for 5-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 6-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/06
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/06?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/06?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/06?page=4
# ✅ Finished scraping for 6-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 7-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/07
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/07?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/07?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/07?page=4
# ✅ Finished scraping for 7-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 8-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/08
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/08?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/08?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/08?page=4
# ✅ Finished scraping for 8-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 9-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/09
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/09?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/09?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/09?page=4
# ✅ Finished scraping for 9-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 10-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/10
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/10?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/10?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/10?page=4
# ✅ Finished scraping for 10-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 11-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/11
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/11?page=2
# ✅ Finished scraping for 11-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 12-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/12
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/12?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/12?page=3
# ✅ Finished scraping for 12-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 13-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/13
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/13?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/13?page=3
# ✅ Finished scraping for 13-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 14-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/14
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/14?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/14?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/14?page=4
# ✅ Finished scraping for 14-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 15-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/15
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/15?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/15?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/15?page=4
# ✅ Finished scraping for 15-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 16-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/16
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/16?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/16?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/16?page=4
# ✅ Finished scraping for 16-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 17-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/17
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/17?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/17?page=3
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/17?page=4
# ✅ Finished scraping for 17-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 18-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/18
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/18?page=2
# ✅ Finished scraping for 18-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 19-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/19
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/19?page=2
# ✅ Finished scraping for 19-2-2023. Total articles: 0
#
# 📅 Starting scrape for date: 20-2-2023
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/20
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/20?page=2
#
# 🔎 Scraping URL: https://www.wsj.com/news/archive/2023/02/20?page=3
# ✅ Finished scraping for 20-2-2023. Total articles: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 147
#     144 year_to_scrape = 2023     # Year to scrape
#     145 waiting_time = 7          # Time to wait between requests (seconds)
# --> 147 searching(year_to_scrape, waiting_time)
#     148 print("\n🏁 Scraping completed successfully.")
#
# Cell In[4], line 141, in searching(target_year, waiting_time)
#     139 print(f"\n📅 Starting scrape for date: {day}-{month}-{year}")
#     140 scraper.get_elements_from_web(year, month, day, waiting_time)
# --> 141 time.sleep(waiting_time)
#
# KeyboardInterrupt:
