# %%
import sqlite3

# Path to data base
db_path = r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"

# connect to the database
conn = sqlite3.connect(db_path)
c = conn.cursor()

# show tables in the database
c.execute("SELECT name FROM sqlite_master WHERE type='table'")
tables = c.fetchall()

print("Tabellen in der Datenbank:")
for t in tables:
    print(" -", t[0])

conn.close()
# Out:
# Tabellen in der Datenbank:
#  - articles_index
#  - sqlite_sequence
#  - article
#  - exploration

# %%
conn = sqlite3.connect(db_path)
c = conn.cursor()

# Show 5 articles with non-empty corpus
c.execute("""
    SELECT a.article_id, a.title, a.sub_title, a.corpus, i.link
    FROM article a
    JOIN articles_index i ON a.index_id = i.id
    WHERE a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
    LIMIT 5
""")
articles = c.fetchall()

for article in articles:
    print("\n Title:", article[1])
    print(" Link:", article[4])
    print(" Corpus:", article[3][:300], "...\n")

    

conn.close()
# Out:
#  Title: Baidu Terminates $3.6B Deal to Buy JOYY’s China Live-Streaming Business
#  Link: https://www.wsj.com/business/telecom/baidu-terminates-3-6b-deal-to-buy-joyys-china-live-streaming-business-d68f9d86
#  Corpus: Advertisement
# BUSINESS
# TELECOM
# Baidu Terminates $3.6B Deal to Buy JOYY’s China Live-Streaming Business
# As of the end of December, the closing conditions for the share purchase agreement had yet to be fully satisfied, Baidu said
# By
# P.R. Venkat
# Follow
# Jan. 1, 2024 6:44 pm ET
# Gift unlocked article
# List ...
#
#
#  Title: The Military’s Phantom ‘Extremists’
#  Link: https://www.wsj.com/opinion/military-extremists-report-institute-for-defense-analyses-pentagon-lloyd-austin-97619f4d
#  Corpus: Advertisement
# OPINION
# REVIEW & OUTLOOK
# Follow
# The Military’s Phantom ‘Extremists’
# An independent study puts to rest another false media narrative.
# By
# The Editorial Board
# Follow
# Jan. 1, 2024 5:45 pm ET
# 834
# Gift unlocked article
# Listen
# (3 min)
# Secretary of Defense Lloyd Austin PHOTO: SAUL LOEB/AGENCE  ...
#
#
#  Title: Double Dipping in Opioid Lawsuits
#  Link: https://www.wsj.com/opinion/double-dipping-in-opioid-lawsuits-optumrx-motley-rice-6dab5dcb
#  Corpus: Advertisement
# OPINION
# REVIEW & OUTLOOK
# Follow
# Double Dipping in Opioid Lawsuits
# OptumRx seeks to disqualify Motley Rice for a conflict of interest.
# By
# The Editorial Board
# Follow
# Jan. 1, 2024 5:45 pm ET
# 116
# Gift unlocked article
# Listen
# (3 min)
# PHOTO: ANDREW KELLY/REUTERS
# The plaintiffs bar never met  ...
#
#
#  Title: Xi Jinping Says Happy New Year
#  Link: https://www.wsj.com/opinion/xi-jinping-says-happy-new-year-taiwan-election-bd8cf5a9
#  Corpus: Advertisement
# OPINION
# REVIEW & OUTLOOK
# Follow
# Xi Jinping Says Happy New Year
# China’s leader tries to influence Taiwan’s Jan. 13 election.
# By
# The Editorial Board
# Follow
# Jan. 1, 2024 5:43 pm ET
# 129
# Gift unlocked article
# Listen
# (2 min)
# Chinese President Xi Jinping delivers 2024 New Year address, Beijin ...
#
#
#  Title: Israel Reshuffles Forces, Prepares for Long-Term Conflict in Gaza
#  Link: https://www.wsj.com/world/middle-east/israel-reshuffles-forces-prepares-for-long-term-conflict-in-gaza-74c87309
#  Corpus: Israel Reshuffles Forces, Prepares for Long-Term Conflict in Gaza
# Resisting pressure from U.S. to wind down the war, Israel looks to sustain lower-intensity fighting
# Israeli soldiers organizing munitions Monday along Israel’s southern border with the Gaza Strip. AMIR LEVY/GETTY IMAGES
# By Carrie Kell ...

# %%
# Connect to the database again to count articles with real content
conn = sqlite3.connect(db_path)
c = conn.cursor()

# count articles with non-empty corpus
c.execute("""
    SELECT COUNT(*) FROM article
    WHERE corpus IS NOT NULL AND corpus != '' AND corpus != 'not found'
""")

count = c.fetchone()[0]
print(f" Artikel mit echtem Inhalt: {count}")

conn.close()
# Out:
#  Artikel mit echtem Inhalt: 18472

# %%
import sqlite3
import pandas as pd

# Pfad zur DB
db_path =  r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"
conn = sqlite3.connect(db_path)
c = conn.cursor()

# SQL: echte Artikel zählen, nach Datum gruppiert
query = """
SELECT 
    ai.year, ai.month, ai.day, COUNT(*) as count
FROM article a
JOIN articles_index ai ON a.index_id = ai.id
WHERE a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
GROUP BY ai.year, ai.month, ai.day
ORDER BY ai.year, ai.month, ai.day
"""

df = pd.read_sql_query(query, conn)
conn.close()

# Datum als echte Spalte formatieren
df['date'] = pd.to_datetime(df['year'] + '-' + df['month'].str.zfill(2) + '-' + df['day'].str.zfill(2))
df = df[['date', 'count']].sort_values('date')

# ✅ Zeige Ergebnis
print(df[df['count'] < 30])
# Out:
#           date  count
# 5   2024-01-14     25
# 131 2024-02-17     26
# 132 2024-02-18     26
# 135 2024-02-20     28
# 138 2024-02-24     25
# 176 2024-04-27     27
# 212 2024-05-04     29
# 196 2024-05-18     26
# 201 2024-05-22     10
# 204 2024-05-25     25
# 205 2024-05-26     20
# 218 2024-06-01     28
# 224 2024-06-15     24
# 232 2024-06-22     28
# 239 2024-06-29     28
# 270 2024-07-05      1
# 260 2024-07-20     27
# 268 2024-07-28     14
# 269 2024-07-29      2
# 271 2024-08-11      1
# 272 2024-08-16      1
# 273 2024-08-22      1
# 278 2024-08-31     28
# 285 2024-09-01     27
# 57  2024-10-05     26
# 34  2024-10-12     29
# 41  2024-10-19     23
# 49  2024-10-26     28
# 91  2024-11-09     26
# 69  2024-11-16     25
# 77  2024-11-23     24
# 85  2024-11-30     25
# 120 2024-12-07     29
# 97  2024-12-14     21
# 105 2024-12-21     21
# 112 2024-12-28     18

# %%
# Verbindung aufbauen
conn = sqlite3.connect(db_path)

# SQL: Artikel zählen pro Tag (nur mit echtem Inhalt)
query = """
SELECT 
    ai.year, ai.month, ai.day,
    COUNT(DISTINCT a.article_id) as article_count
FROM article a
JOIN articles_index ai ON a.index_id = ai.id
WHERE a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
GROUP BY ai.year, ai.month, ai.day
HAVING article_count < 30
ORDER BY ai.year, ai.month, ai.day
"""


df = pd.read_sql_query(query, conn)
conn.close()

# Formatierte Datumsspalte
df['date'] = pd.to_datetime(df['year'] + '-' + df['month'].str.zfill(2) + '-' + df['day'].str.zfill(2))
df = df[['date', 'article_count']]

# Ergebnis anzeigen
print("📅 Tage mit weniger als 30 Artikeln:")
print(df)
# Out:
# 📅 Tage mit weniger als 30 Artikeln:
#          date  article_count
# 0  2024-01-14             25
# 1  2024-10-12             29
# 2  2024-10-19             23
# 3  2024-10-26             28
# 4  2024-10-05             26
# 5  2024-11-16             25
# 6  2024-11-23             24
# 7  2024-11-30             25
# 8  2024-11-09             26
# 9  2024-12-14             21
# 10 2024-12-21             21
# 11 2024-12-28             18
# 12 2024-12-07             29
# 13 2024-02-17             26
# 14 2024-02-18             26
# 15 2024-02-20             28
# 16 2024-02-24             25
# 17 2024-04-27             27
# 18 2024-05-18             26
# 19 2024-05-22             10
# 20 2024-05-25             25
# 21 2024-05-26             20
# 22 2024-05-04             29
# 23 2024-06-01             28
# 24 2024-06-15             24
# 25 2024-06-22             28
# 26 2024-06-29             28
# 27 2024-07-20             27
# 28 2024-07-28             14
# 29 2024-07-29              2
# 30 2024-07-05              1
# 31 2024-08-11              1
# 32 2024-08-16              1
# 33 2024-08-22              1
# 34 2024-08-31             28
# 35 2024-09-01             27

# %%
import sqlite3
import pandas as pd

# Pfad zur DB
db_path =  r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"
conn = sqlite3.connect(db_path)
c = conn.cursor()

# SQL: Artikel zählen pro Tag (nur mit echtem Inhalt)
query = """
SELECT 
    ai.year, ai.month, ai.day,
    COUNT(*) as article_count
FROM article a
JOIN articles_index ai ON a.index_id = ai.id
GROUP BY ai.year, ai.month, ai.day
ORDER BY ai.year, ai.month, ai.day
"""

df = pd.read_sql_query(query, conn)
conn.close()

# Formatierte Datumsspalte
df['date'] = pd.to_datetime(df['year'] + '-' + df['month'].str.zfill(2) + '-' + df['day'].str.zfill(2))


# Ergebnis anzeigen
print(df[df['date'] == '2024-08-25'][['date', 'article_count']])
# Out:
# Empty DataFrame
# Columns: [date, article_count]
# Index: []

# %%
import pandas as pd
import sqlite3

# Verbindung aufbauen
# Pfad zur DB
db_path =  r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"
conn = sqlite3.connect(db_path)

# SQL: Lade alle Tage mit weniger als 30 Artikeln
query = """
SELECT 
    ai.year, ai.month, ai.day,
    COUNT(DISTINCT a.article_id) as article_count
FROM articles_index ai
LEFT JOIN article a ON a.index_id = ai.id
    AND a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
GROUP BY ai.year, ai.month, ai.day
HAVING article_count < 30
ORDER BY ai.year, ai.month, ai.day;
"""

# In DataFrame laden
df = pd.read_sql_query(query, conn)
conn.close()

# Datum erzeugen
df['month'] = df['month'].astype(str).str.zfill(2)
df['day'] = df['day'].astype(str).str.zfill(2)
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'] + '-' + df['day'])


# Ausgabe
print("Tage mit weniger als 30 Artikeln:")
print(df[['date', 'article_count']])
# Out:
# Tage mit weniger als 30 Artikeln:
#          date  article_count
# 0  2024-01-14             25
# 1  2024-10-12             29
# 2  2024-10-19             23
# 3  2024-10-26             28
# 4  2024-10-05             26
# 5  2024-11-16             25
# 6  2024-11-23             24
# 7  2024-11-30             25
# 8  2024-11-09             26
# 9  2024-12-14             21
# 10 2024-12-21             21
# 11 2024-12-28             18
# 12 2024-12-07             29
# 13 2024-02-17             26
# 14 2024-02-18             26
# 15 2024-02-24             25
# 16 2024-03-02             29
# 17 2024-03-30             28
# 18 2024-04-27             27
# 19 2024-05-18             26
# 20 2024-05-25             25
# 21 2024-05-26             20
# 22 2024-05-04             29
# 23 2024-06-01             28
# 24 2024-06-15             24
# 25 2024-06-22             28
# 26 2024-06-29             28
# 27 2024-07-20             27
# 28 2024-07-06             25
# 29 2024-08-18              8
# 30 2024-08-19              0
# 31 2024-08-02              0
# 32 2024-08-20              0
# 33 2024-08-21              0
# 34 2024-08-22              1
# 35 2024-08-23              0
# 36 2024-08-24              1
# 37 2024-08-25              0
# 38 2024-08-26              0
# 39 2024-08-27              0
# 40 2024-08-31             28
# 41 2024-09-01             27

# %%
import sqlite3
import time
from web_scrap import Search4Articles
import pandas as pd

# Absoluter Pfad zur DB
DB_PATH = r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"

# Verbindung aufbauen
conn = sqlite3.connect(DB_PATH)

# SQL: Artikel zählen pro Tag (nur mit echtem Inhalt)
query = """
SELECT ai.year, ai.month, ai.day,
    COUNT(DISTINCT a.article_id) as article_count
FROM articles_index ai
LEFT JOIN article a ON a.index_id = ai.id
    AND a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
GROUP BY ai.year, ai.month, ai.day
HAVING article_count < 30
ORDER BY ai.year, ai.month, ai.day
"""

# Lade Daten in DataFrame
df = pd.read_sql_query(query, conn)
conn.close()

# Datumsspalte erzeugen 
df['month'] = df['month'].astype(str).str.zfill(2)
df['day'] = df['day'].astype(str).str.zfill(2)
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'] + '-' + df['day'])

# 📦 Erzeuge Liste von (year, month, day)
# Ensure values are int
df[['year', 'month', 'day']] = df[['year', 'month', 'day']].astype(int)
custom_days = list(df[['year', 'month', 'day']].itertuples(index=False, name=None))

# Ausgabe zur Kontrolle
print("📅 Tage mit weniger als 30 Artikeln:")
print(df[['date', 'article_count']])


def has_enough_articles(year, month, day, db_name=DB_PATH, max_articles=30):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    c.execute("""
        SELECT COUNT(DISTINCT a.article_id)
        FROM articles_index ai
        LEFT JOIN article a ON a.index_id = ai.id
            AND a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
        WHERE ai.year = ? AND ai.month = ? AND ai.day = ?
    """, (year, month, day))
    count = c.fetchone()[0]
    conn.close()
    return count >= max_articles

if __name__ == "__main__":
    max_articles_per_day = 30

    print("📅 Starte gezieltes Scraping für benutzerdefinierte Tage...")

    sa = Search4Articles(db_name=DB_PATH)

    for (year, month, day) in custom_days:
        print(f"🔍 Überprüfe {year}-{month:02d}-{day:02d}...")

        if has_enough_articles(year, month, day, max_articles=max_articles_per_day):
            print("✅ Genug Artikel vorhanden – überspringe.")
            continue

        print("🚀 Lade fehlende Artikel...")
        sa.navigation(max_per_day=max_articles_per_day, year=year, month=month, day=day)
        print("✅ Fertig mit diesem Tag.\n")
        time.sleep(10)

    sa.driver.quit()
    print("🏁 Alle angegebenen Tage wurden überprüft.")
# Out:
# 📅 Tage mit weniger als 30 Artikeln:
#          date  article_count
# 0  2024-01-14             25
# 1  2024-10-12             29
# 2  2024-10-19             23
# 3  2024-10-26             28
# 4  2024-10-05             26
# 5  2024-11-16             25
# 6  2024-11-23             24
# 7  2024-11-30             25
# 8  2024-11-09             26
# 9  2024-12-14             21
# 10 2024-12-21             21
# 11 2024-12-28             18
# 12 2024-12-07             29
# 13 2024-02-17             26
# 14 2024-02-18             26
# 15 2024-02-24             25
# 16 2024-03-02             29
# 17 2024-03-30             28
# 18 2024-04-27             27
# 19 2024-05-18             26
# 20 2024-05-25             25
# 21 2024-05-26             20
# 22 2024-05-04             29
# 23 2024-06-01             28
# 24 2024-06-15             24
# 25 2024-06-22             28
# 26 2024-06-29             28
# 27 2024-07-20             27
# 28 2024-07-06             25
# 29 2024-08-18              8
# 30 2024-08-19              0
# 31 2024-08-02              0
# 32 2024-08-20              0
# 33 2024-08-21              0
# 34 2024-08-22              1
# 35 2024-08-23              0
# 36 2024-08-24              1
# 37 2024-08-25              0
# 38 2024-08-26              0
# 39 2024-08-27              0
# 40 2024-08-31             28
# 41 2024-09-01             27
# 📅 Starte gezieltes Scraping für benutzerdefinierte Tage...
# 🔍 Überprüfe 2024-01-14...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-01-14: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-10-12...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-10-12: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-10-19...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-10-19: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-10-26...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-10-26: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-10-05...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-10-05: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-11-16...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-11-16: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-11-23...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-11-23: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-11-30...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-11-30: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-11-09...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-11-09: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-12-14...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-12-14: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-12-21...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-12-21: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-12-28...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-12-28: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-12-07...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-12-07: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-02-17...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-02-17: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-02-18...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-02-18: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-02-24...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-02-24: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-03-02...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-03-02: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-03-30...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-03-30: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-04-27...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-04-27: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-05-18...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-05-18: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-05-25...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-05-25: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-05-26...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-05-26: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-05-04...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-05-04: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-06-01...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-06-01: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-06-15...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-06-15: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-06-22...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-06-22: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-06-29...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-06-29: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-07-20...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-07-20: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-07-06...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-07-06: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-18...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-18: max. 30 Article
# ➡️ Öffne Artikel 16937: https://www.wsj.com/opinion/the-convention-games-make-the-dnc-more-like-the-olympics-486eab1b
# ⚠️ Kein brauchbarer Inhalt – Artikel 16937 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16938: https://www.wsj.com/opinion/mexico-flirts-with-dictatorship-amlo-constitutional-amendment-88867b2d
# ⚠️ Kein brauchbarer Inhalt – Artikel 16938 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16939: https://www.wsj.com/opinion/with-biden-gone-delaware-could-flip-2024-presidential-election-b271bf1c
# ⚠️ Kein brauchbarer Inhalt – Artikel 16939 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16940: https://www.wsj.com/world/americas/argentinas-milei-finds-it-hard-to-decouple-from-china-6faae47f
# ⚠️ Kein brauchbarer Inhalt – Artikel 16940 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16941: https://www.wsj.com/sports/kasia-niewiadoma-tour-de-france-femmes-09f3f2d6
# ⚠️ Kein brauchbarer Inhalt – Artikel 16941 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16942: https://www.wsj.com/opinion/here-comes-kamalas-mortgage-forgiveness-housing-prices-loans-dc37091b
# ⚠️ Kein brauchbarer Inhalt – Artikel 16942 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16943: https://www.wsj.com/opinion/vance-flips-the-fact-check-script-cbs-unwittingly-reveals-harris-radicalism-68902725
# ⚠️ Kein brauchbarer Inhalt – Artikel 16943 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16944: https://www.wsj.com/arts-culture/books/bite-review-an-incisive-natural-history-ee82fc3b
# ⚠️ Kein brauchbarer Inhalt – Artikel 16944 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16945: https://www.wsj.com/opinion/asking-for-an-olympics-without-politics-de598d86
# ⚠️ Kein brauchbarer Inhalt – Artikel 16945 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16946: https://www.wsj.com/opinion/boeing-737-max-crashes-mcas-pilot-error-efa6fa3a
# ⚠️ Kein brauchbarer Inhalt – Artikel 16946 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16947: https://www.wsj.com/opinion/the-changing-fields-of-education-and-medicine-e565730f
# ⚠️ Kein brauchbarer Inhalt – Artikel 16947 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16948: https://www.wsj.com/opinion/a-school-of-civic-leadership-is-coming-to-a-college-near-you-a9420512
# ⚠️ Kein brauchbarer Inhalt – Artikel 16948 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16949: https://www.wsj.com/opinion/they-put-trump-though-hell-86be8ac5
# ⚠️ Kein brauchbarer Inhalt – Artikel 16949 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16950: https://www.wsj.com/tech/cybersecurity/cybersecurity-questions-wifi-passwords-9aaf366c
# ⚠️ Kein brauchbarer Inhalt – Artikel 16950 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16951: https://www.wsj.com/politics/elections/trump-and-harris-duke-it-out-on-social-media-1fcb218a
# ⚠️ Kein brauchbarer Inhalt – Artikel 16951 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16952: https://www.wsj.com/real-estate/luxury-homes/house-restoration-renova-nevada-c55c97dd
# ⚠️ Kein brauchbarer Inhalt – Artikel 16952 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16953: https://www.wsj.com/tech/sam-altman-openai-humanness-iris-scanning-4d0e1dab
# ⚠️ Kein brauchbarer Inhalt – Artikel 16953 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16954: https://www.wsj.com/world/russia/a-russian-mothers-pleas-to-find-a-captured-conscript-are-met-with-silence-34b81e94
# ⚠️ Kein brauchbarer Inhalt – Artikel 16954 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16955: https://www.wsj.com/lifestyle/cars/the-bravest-driver-in-new-york-city-gets-around-in-a-1925-rolls-royce-86c9414a
# ⚠️ Kein brauchbarer Inhalt – Artikel 16955 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16956: https://www.wsj.com/business/retail/berkshire-hathaway-likes-ulta-beauty-should-you-bdce9393
# ⚠️ Kein brauchbarer Inhalt – Artikel 16956 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16957: https://www.wsj.com/personal-finance/credit-score-dating-apps-f1871c30
# ⚠️ Kein brauchbarer Inhalt – Artikel 16957 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16958: https://www.wsj.com/sports/football/college-transfers-power-five-conferences-aee82375
# ⚠️ Kein brauchbarer Inhalt – Artikel 16958 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-19...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-19: max. 30 Article
# ➡️ Öffne Artikel 16971: https://www.wsj.com/articles/maersk-to-limit-canada-bound-cargo-ahead-of-possible-rail-work-stoppage-6b7e1351
# ⚠️ Kein brauchbarer Inhalt – Artikel 16971 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16972: https://www.wsj.com/world/europe/superyacht-sinks-sicily-mike-lynch-search-and-rescue-8fac03e1
# ⚠️ Kein brauchbarer Inhalt – Artikel 16972 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16973: https://www.wsj.com/opinion/dnc-platform-2024-kamala-harris-government-democrats-joe-biden-2e16e695
# ⚠️ Kein brauchbarer Inhalt – Artikel 16973 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16974: https://www.wsj.com/opinion/hamas-rejects-hostage-deal-israel-gaza-biden-administration-doha-tel-aviv-a6904dc6
# ⚠️ Kein brauchbarer Inhalt – Artikel 16974 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16975: https://www.wsj.com/opinion/harley-davidson-thailand-tariffs-manufacturing-donald-trump-joe-biden-kamala-harris-ae86c850
# ⚠️ Kein brauchbarer Inhalt – Artikel 16975 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16976: https://www.wsj.com/opinion/poor-unwanted-joe-biden-administration-harris-record-election-51378a8d
# ⚠️ Kein brauchbarer Inhalt – Artikel 16976 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16977: https://www.wsj.com/opinion/stale-foreign-policy-ideas-imperil-america-dangerous-world-national-security-c4d45348
# ⚠️ Kein brauchbarer Inhalt – Artikel 16977 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16978: https://www.wsj.com/opinion/greedflation-is-high-priced-baloney-economy-policy-9418cf4e
# ⚠️ Kein brauchbarer Inhalt – Artikel 16978 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16979: https://www.wsj.com/world/middle-east/hamas-claims-attempted-suicide-bombing-as-cease-fire-diplomacy-resumes-f13b4f0f
# ⚠️ Kein brauchbarer Inhalt – Artikel 16979 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16980: https://www.wsj.com/arts-culture/music/rocky-mountain-highs-at-the-aspen-music-festival-and-school-4fc49c1f
# ⚠️ Kein brauchbarer Inhalt – Artikel 16980 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16981: https://www.wsj.com/opinion/q-a-what-im-expecting-at-the-dnc-this-week-5c72d1b8
# ⚠️ Kein brauchbarer Inhalt – Artikel 16981 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16982: https://www.wsj.com/real-estate/luxury-homes/jeremy-renner-los-angeles-home-6df1c53a
# ⚠️ Kein brauchbarer Inhalt – Artikel 16982 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16983: https://www.wsj.com/business/harley-davidson-changes-dei-policy-following-activist-pressure-b544ba26
# ⚠️ Kein brauchbarer Inhalt – Artikel 16983 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16984: https://www.wsj.com/opinion/is-putins-inner-circle-wobbling-russia-critics-war-1eb59e51
# ⚠️ Kein brauchbarer Inhalt – Artikel 16984 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16985: https://www.wsj.com/articles/tax-firm-carrying-on-arthur-andersen-brand-explores-ipo-e35c4136
# ⚠️ Kein brauchbarer Inhalt – Artikel 16985 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16986: https://www.wsj.com/finance/regulation/sec-accuses-carl-icahn-of-concealing-stock-pledges-841ead05
# ⚠️ Kein brauchbarer Inhalt – Artikel 16986 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16987: https://www.wsj.com/articles/the-50-year-old-technology-that-brands-and-retailers-are-trying-to-quit-1fbfab3f
# ⚠️ Kein brauchbarer Inhalt – Artikel 16987 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16988: https://www.wsj.com/opinion/biden-rewrites-title-ix-to-impose-a-tyranny-of-feeling-trans-gender-identity-3f04a485
# ⚠️ Kein brauchbarer Inhalt – Artikel 16988 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16989: https://www.wsj.com/articles/early-lead-tuesday-crossword-august-20-ebe55884
# ⚠️ Kein brauchbarer Inhalt – Artikel 16989 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16990: https://www.wsj.com/business/media/phil-donahue-daytime-talk-show-pioneer-dies-at-88-f4bac816
# ⚠️ Kein brauchbarer Inhalt – Artikel 16990 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16991: https://www.wsj.com/opinion/meanwhile-back-in-california-21d89dc8
# ⚠️ Kein brauchbarer Inhalt – Artikel 16991 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16992: https://www.wsj.com/opinion/kamala-harris-tries-to-forget-joe-biden-election-2024-d45716e1
# ⚠️ Kein brauchbarer Inhalt – Artikel 16992 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16993: https://www.wsj.com/opinion/jd-vance-harris-wages-war-on-us-energy-inflation-net-zero-2024-presidential-election-aaf19e44
# ⚠️ Kein brauchbarer Inhalt – Artikel 16993 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16994: https://www.wsj.com/tech/ai/amd-deal-shows-ai-chip-business-isnt-just-about-chips-81fb46d9
# ⚠️ Kein brauchbarer Inhalt – Artikel 16994 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16995: https://www.wsj.com/arts-culture/books/the-stadium-review-americas-theater-01f394ba
# ⚠️ Kein brauchbarer Inhalt – Artikel 16995 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16996: https://www.wsj.com/world/ukraine-strikes-three-bridges-in-russias-kursk-region-ed88d0e6
# ⚠️ Kein brauchbarer Inhalt – Artikel 16996 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16997: https://www.wsj.com/sports/basketball/guerschon-yabusele-france-olympics-dunk-lebron-c6c74ad0
# ⚠️ Kein brauchbarer Inhalt – Artikel 16997 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16998: https://www.wsj.com/articles/companies-havent-abandoned-sustainability-theyre-just-talking-about-it-less-acd0e85f
# ⚠️ Kein brauchbarer Inhalt – Artikel 16998 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 16999: https://www.wsj.com/business/estee-lauders-longtime-ceo-fabrizio-freda-to-retire-0d9cb186
# ⚠️ Kein brauchbarer Inhalt – Artikel 16999 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17000: https://www.wsj.com/articles/guess-chief-financial-officer-markus-neubrand-resigns-6c58da2a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17000 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-02...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-02: max. 30 Article
# ➡️ Öffne Artikel 15782: https://www.wsj.com/world/middle-east/israel-u-s-prepare-for-severe-iranian-retaliation-c721c0bf
# ⚠️ Kein brauchbarer Inhalt – Artikel 15782 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15783: https://www.wsj.com/us-news/tech-failings-plagued-secret-service-at-trump-rally-49d2286e
# ⚠️ Kein brauchbarer Inhalt – Artikel 15783 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15784: https://www.wsj.com/style/design/what-i-wish-i-knew-before-i-downsized-homeowners-on-their-missteps-and-smart-solutions-9e6b2239
# ⚠️ Kein brauchbarer Inhalt – Artikel 15784 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15785: https://www.wsj.com/business/autos/judge-questions-teslas-argument-for-restoring-musks-pay-package-0f03c2d1
# ⚠️ Kein brauchbarer Inhalt – Artikel 15785 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15786: https://www.wsj.com/business/earnings/intel-ceo-pat-gelsingers-dream-job-takes-a-nightmarish-turn-97dd98e3
# ⚠️ Kein brauchbarer Inhalt – Artikel 15786 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15787: https://www.wsj.com/opinion/recession-rumors-economy-unemployment-stocks-jerome-powell-kamala-harris-donald-trump-40aa9f20
# ⚠️ Kein brauchbarer Inhalt – Artikel 15787 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15788: https://www.wsj.com/opinion/biden-iran-israel-hamas-ismail-haniyeh-benjamin-netanyahu-66303f59
# ⚠️ Kein brauchbarer Inhalt – Artikel 15788 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15789: https://www.wsj.com/opinion/chevron-leaves-california-energy-oil-gas-refineries-regulation-434d7a38
# ⚠️ Kein brauchbarer Inhalt – Artikel 15789 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15790: https://www.wsj.com/opinion/medicaid-expansion-biden-administration-kamala-harris-roy-cooper-north-carolina-42e8e209
# ⚠️ Kein brauchbarer Inhalt – Artikel 15790 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15791: https://www.wsj.com/opinion/what-aspiring-economists-arent-being-taught-a3f73484
# ⚠️ Kein brauchbarer Inhalt – Artikel 15791 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15792: https://www.wsj.com/finance/stocks/the-score-crowdstrike-apple-intel-and-more-stocks-that-defined-the-week-c745ac7a
# ⚠️ Kein brauchbarer Inhalt – Artikel 15792 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15793: https://www.wsj.com/opinion/nba-kerfuffle-and-streamings-future-ad-free-subscrition-access-lots-of-content-lost-dream-91567c4a
# ⚠️ Kein brauchbarer Inhalt – Artikel 15793 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15794: https://www.wsj.com/opinion/iran-counts-on-american-weakness-to-check-israeli-strength-biden-ceasefire-426b492b
# ⚠️ Kein brauchbarer Inhalt – Artikel 15794 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15795: https://www.wsj.com/arts-culture/books/mrs-bridge-unconventional-portrait-of-a-conventional-life-e9607007
# ⚠️ Kein brauchbarer Inhalt – Artikel 15795 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15796: https://www.wsj.com/arts-culture/fine-art/contemporary-bodegones-and-monomythology-reviews-yesterdays-subjects-todays-artists-airdigital-993a9670
# ⚠️ Kein brauchbarer Inhalt – Artikel 15796 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15797: https://www.wsj.com/style/fashion/luxury-brands-are-betting-on-ties-again-heres-why-neckwear-means-money-ca9083cb
# ⚠️ Kein brauchbarer Inhalt – Artikel 15797 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15798: https://www.wsj.com/business/energy-oil/chevron-to-leave-california-for-texas-as-regulations-mount-in-golden-state-d58e170c
# ⚠️ Kein brauchbarer Inhalt – Artikel 15798 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15799: https://www.wsj.com/real-estate/luxury-homes/olympic-gold-medalist-shaun-white-sells-los-angeles-home-for-3-925-million-6b9dde47
# ⚠️ Kein brauchbarer Inhalt – Artikel 15799 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15800: https://www.wsj.com/finance/stocks/global-stocks-markets-dow-news-08-02-2024-9c1e3b7d
# ⚠️ Kein brauchbarer Inhalt – Artikel 15800 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15801: https://www.wsj.com/politics/policy/trump-floats-end-to-taxes-on-social-security-benefits-a738b27b
# ⚠️ Kein brauchbarer Inhalt – Artikel 15801 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15802: https://www.wsj.com/politics/elections/kamala-harris-vp-pick-candidates-4c810ea0
# ⚠️ Kein brauchbarer Inhalt – Artikel 15802 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15803: https://www.wsj.com/economy/jobs/jobs-report-july-unemployment-economy-8b7e6db7
# ⚠️ Kein brauchbarer Inhalt – Artikel 15803 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15804: https://www.wsj.com/tech/u-s-sues-tiktok-alleging-it-violated-child-privacy-law-0e787c16
# ⚠️ Kein brauchbarer Inhalt – Artikel 15804 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15805: https://www.wsj.com/articles/well-that-took-a-funny-turn-saturday-crossword-august-3-74f138a6
# ⚠️ Kein brauchbarer Inhalt – Artikel 15805 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15806: https://www.wsj.com/articles/labyrinth-saturday-variety-puzzle-august-3-bf09827b
# ⚠️ Kein brauchbarer Inhalt – Artikel 15806 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15807: https://www.wsj.com/style/fashion/white-diamonds-lose-cachet-colored-engagement-rings-a-guide-801dd761
# ⚠️ Kein brauchbarer Inhalt – Artikel 15807 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15808: https://www.wsj.com/us-news/education/harvard-university-to-launch-search-for-president-in-2026-a5d8ab8d
# ⚠️ Kein brauchbarer Inhalt – Artikel 15808 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15809: https://www.wsj.com/lifestyle/travel/outer-hebrides-scotlands-most-famous-road-trip-north-coast-500-take-this-one-instead-ac5d40bb
# ⚠️ Kein brauchbarer Inhalt – Artikel 15809 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15810: https://www.wsj.com/arts-culture/books/14-books-we-read-this-week-3a095317
# ⚠️ Kein brauchbarer Inhalt – Artikel 15810 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 15811: https://www.wsj.com/style/fashion/you-can-wear-the-new-dressy-mens-jeans-anywhere-ok-maybe-not-a-wedding-07627383
# ⚠️ Kein brauchbarer Inhalt – Artikel 15811 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-20...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-20: max. 30 Article
# ➡️ Öffne Artikel 17034: https://www.wsj.com/business/airlines/alaska-air-hawaiian-airlines-clear-key-antitrust-hurdle-96c334d8
# ⚠️ Kein brauchbarer Inhalt – Artikel 17034 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17035: https://www.wsj.com/business/hospitality/hyatt-to-buy-standard-international-in-lifestyle-effort-b6a8587b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17035 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17036: https://www.wsj.com/opinion/democrats-democratic-norms-kamala-harris-adam-schiff-stacey-abrams-donald-trump-6e345206
# ⚠️ Kein brauchbarer Inhalt – Artikel 17036 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17037: https://www.wsj.com/opinion/kamala-harris-corporate-tax-increase-business-wages-2024-election-746ee509
# ⚠️ Kein brauchbarer Inhalt – Artikel 17037 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17038: https://www.wsj.com/opinion/china-antimony-exports-restrictions-u-s-national-security-idaho-perpetua-resources-e8b701b8
# ⚠️ Kein brauchbarer Inhalt – Artikel 17038 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17039: https://www.wsj.com/opinion/title-ix-rule-supreme-court-biden-administration-education-department-4d0ce6f0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17039 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17040: https://www.wsj.com/opinion/bloomberg-spends-wisely-on-hbcus-outperform-higher-ranked-institutions-f3d40931
# ⚠️ Kein brauchbarer Inhalt – Artikel 17040 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17041: https://www.wsj.com/opinion/biden-sees-a-very-fine-point-on-both-sides-dnc-antisemites-protest-israel-59630d75
# ⚠️ Kein brauchbarer Inhalt – Artikel 17041 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17042: https://www.wsj.com/arts-culture/music/f-1-trillion-by-post-malone-review-country-morgan-wallen-dolly-parton-tim-mcgraw-e51ff543
# ⚠️ Kein brauchbarer Inhalt – Artikel 17042 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17043: https://www.wsj.com/world/middle-east/israel-retrieves-bodies-of-six-hostages-in-gaza-ae83da9f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17043 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17044: https://www.wsj.com/opinion/kamala-harris-said-yes-to-inflation-deciding-vote-on-programs-that-led-directly-to-it-885882b5
# ⚠️ Kein brauchbarer Inhalt – Artikel 17044 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17045: https://www.wsj.com/opinion/washington-can-give-america-a-raise-kamala-harris-federal-minimum-wage-642d601a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17045 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17046: https://www.wsj.com/opinion/what-kamala-owes-joe-dnc-2024-election-national-security-50909f7e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17046 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17047: https://www.wsj.com/sports/tennis/american-tennis-us-open-coco-gauff-b5c265cc
# ⚠️ Kein brauchbarer Inhalt – Artikel 17047 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17048: https://www.wsj.com/articles/head-of-the-table-wednesday-crossword-august-21-fc25e1f7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17048 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17049: https://www.wsj.com/finance/commodities-futures/a-natural-gas-glut-is-forcing-drillers-to-dial-backagain-ff2e56a1
# ⚠️ Kein brauchbarer Inhalt – Artikel 17049 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17050: https://www.wsj.com/style/fashion/democratic-national-convention-kamala-harris-merch-3125250b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17050 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17051: https://www.wsj.com/world/europe/top-banker-lawyer-among-missing-in-yacht-sinking-off-sicily-a35f522b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17051 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17052: https://www.wsj.com/opinion/americans-still-oppose-changing-the-supreme-court-fdc6ae35
# ⚠️ Kein brauchbarer Inhalt – Artikel 17052 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17053: https://www.wsj.com/business/media/edgar-bronfman-submits-4-3-billion-bid-for-redstones-national-amusements-paramount-stake-b7704a11
# ⚠️ Kein brauchbarer Inhalt – Artikel 17053 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17054: https://www.wsj.com/real-estate/luxury-homes/elon-musk-los-angeles-home-7414771f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17054 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17055: https://www.wsj.com/business/airlines/boeing-finds-cracks-in-structure-of-777x-test-jets-8c94087d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17055 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17056: https://www.wsj.com/articles/palo-alto-networks-pushes-forward-with-platform-drive-64b90a75
# ⚠️ Kein brauchbarer Inhalt – Artikel 17056 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17057: https://www.wsj.com/articles/maersk-continues-to-accept-canada-cargo-as-operators-brace-for-rail-stoppage-5f3924dc
# ⚠️ Kein brauchbarer Inhalt – Artikel 17057 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17058: https://www.wsj.com/opinion/project-2025-has-a-long-heritage-the-original-1981-mandate-for-leadership-20fdb794
# ⚠️ Kein brauchbarer Inhalt – Artikel 17058 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17059: https://www.wsj.com/opinion/the-era-of-sound-economics-is-over-business-policy-2024-election-d37c38b0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17059 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17060: https://www.wsj.com/world/middle-east/cellphones-laptops-ai-how-israel-gathers-intelligence-on-hostages-c2bd09d4
# ⚠️ Kein brauchbarer Inhalt – Artikel 17060 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17061: https://www.wsj.com/business/autos/stellantis-to-delay-plans-for-illinois-assembly-plant-counters-union-claims-dfc5adfe
# ⚠️ Kein brauchbarer Inhalt – Artikel 17061 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17062: https://www.wsj.com/arts-culture/books/history-in-flames-review-tracing-the-lost-pages-of-the-past-c9e9b62f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17062 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17063: https://www.wsj.com/arts-culture/television/unbelievably-vegan-with-chef-charity-review-winning-hearts-minds-and-stomachs-on-max-27d2d75d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17063 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-21...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-21: max. 30 Article
# ➡️ Öffne Artikel 17104: https://www.wsj.com/style/fashion/an-office-shirt-that-guarantees-a-perfect-tuck-the-bodysuit-has-grown-up-95c6b9f6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17104 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17105: https://www.wsj.com/world/americas/mexican-judges-strike-in-protest-of-planned-judicial-overhaul-3a5b7afd
# ⚠️ Kein brauchbarer Inhalt – Artikel 17105 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17106: https://www.wsj.com/articles/ftx-says-creditors-overwhelmingly-back-reorganization-plan-627fb1f2
# ⚠️ Kein brauchbarer Inhalt – Artikel 17106 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17107: https://www.wsj.com/finance/regulation/td-bank-sets-aside-2-6-billion-in-3q-for-possible-u-s-anti-money-laundering-penalties-643ef605
# ⚠️ Kein brauchbarer Inhalt – Artikel 17107 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17108: https://www.wsj.com/opinion/dnc-protesters-chicago-police-israel-palestine-brandon-johnson-kamala-harris-929e6299
# ⚠️ Kein brauchbarer Inhalt – Artikel 17108 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17109: https://www.wsj.com/articles/ex-vitol-trader-pleads-guilty-to-additional-bribery-charges-after-conviction-878122ac
# ⚠️ Kein brauchbarer Inhalt – Artikel 17109 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17110: https://www.wsj.com/opinion/kamala-harris-dnc-barack-obama-joe-biden-policy-2024-election-donald-trump-78bacd86
# ⚠️ Kein brauchbarer Inhalt – Artikel 17110 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17111: https://www.wsj.com/business/media/disney-names-board-member-gorman-to-chair-committee-tasked-with-finding-igers-successor-96ee35f1
# ⚠️ Kein brauchbarer Inhalt – Artikel 17111 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17112: https://www.wsj.com/opinion/kidney-transplant-blood-test-moldx-centers-for-medicare-and-medicaid-services-coverage-8e0c2df6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17112 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17113: https://www.wsj.com/opinion/ftc-noncompete-rule-defeated-in-court-ada-brown-lina-khan-ryan-llc-8df69d34
# ⚠️ Kein brauchbarer Inhalt – Artikel 17113 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17114: https://www.wsj.com/opinion/democrats-and-price-controls-708b9292
# ⚠️ Kein brauchbarer Inhalt – Artikel 17114 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17115: https://www.wsj.com/finance/banking/charles-schwab-bank-strategy-3bae69be
# ⚠️ Kein brauchbarer Inhalt – Artikel 17115 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17116: https://www.wsj.com/opinion/democrats-achieved-their-goals-capture-kamala-and-define-trump-dnc-079a3751
# ⚠️ Kein brauchbarer Inhalt – Artikel 17116 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17117: https://www.wsj.com/opinion/a-bitter-biden-bids-goodbye-speech-democratic-national-convention-chicago-election-a77c2a00
# ⚠️ Kein brauchbarer Inhalt – Artikel 17117 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17118: https://www.wsj.com/opinion/kamala-harris-rushes-to-the-center-cultural-radicalism-2024-presidential-election-aa85aaba
# ⚠️ Kein brauchbarer Inhalt – Artikel 17118 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17119: https://www.wsj.com/real-estate/luxury-homes/lake-tahoe-home-sells-for-47-5-million-68093d37
# ⚠️ Kein brauchbarer Inhalt – Artikel 17119 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17120: https://www.wsj.com/articles/climate-tech-vcs-organize-for-kamala-harris-e964cb93
# ⚠️ Kein brauchbarer Inhalt – Artikel 17120 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17121: https://www.wsj.com/opinion/americas-right-got-hungarys-viktor-orban-wrong-china-strategic-partnership-27d5748e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17121 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17122: https://www.wsj.com/opinion/make-elon-musk-head-of-nasa-space-trump-second-term-bedb4a44
# ⚠️ Kein brauchbarer Inhalt – Artikel 17122 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17123: https://www.wsj.com/economy/jobs/jobs-market-was-weaker-than-previously-reported-data-show-f6e72d88
# ⚠️ Kein brauchbarer Inhalt – Artikel 17123 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17124: https://www.wsj.com/opinion/kamala-harris-at-the-dnc-supersized-joe-biden-a28fa123
# ⚠️ Kein brauchbarer Inhalt – Artikel 17124 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17125: https://www.wsj.com/articles/extreme-lifting-thursday-crossword-august-22-a6e2701a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17125 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17126: https://www.wsj.com/economy/central-banking/several-fed-officials-saw-case-for-cutting-rates-in-july-minutes-show-0e4162b9
# ⚠️ Kein brauchbarer Inhalt – Artikel 17126 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17127: https://www.wsj.com/world/europe/mike-lynch-super-yacht-bayesian-mast-426c81df
# ⚠️ Kein brauchbarer Inhalt – Artikel 17127 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17128: https://www.wsj.com/politics/bill-pascrell-long-term-new-jersey-congressman-dies-at-87-e7609b1a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17128 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17129: https://www.wsj.com/style/design/the-return-of-wall-to-wall-carpet-why-americans-want-this-soothing-luxury-now-f0764600
# ⚠️ Kein brauchbarer Inhalt – Artikel 17129 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17130: https://www.wsj.com/world/middle-east/netanyahu-has-a-new-cease-fire-red-line-israels-military-thinks-its-movable-3a72534c
# ⚠️ Kein brauchbarer Inhalt – Artikel 17130 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17131: https://www.wsj.com/us-news/law/lawyer-in-yacht-tragedy-built-star-career-with-unassuming-style-5a3f5fb5
# ⚠️ Kein brauchbarer Inhalt – Artikel 17131 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17132: https://www.wsj.com/personal-finance/how-inflation-and-overspending-are-keeping-gen-z-stuck-in-a-debt-trap-612431ea
# ⚠️ Kein brauchbarer Inhalt – Artikel 17132 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17133: https://www.wsj.com/world/europe/divers-attempt-to-recover-bodies-as-hopes-fade-for-missing-yacht-passengers-f7dae741
# ⚠️ Kein brauchbarer Inhalt – Artikel 17133 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-22...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-22: max. 30 Article
# ➡️ Öffne Artikel 17190: https://www.wsj.com/economy/japans-consumer-prices-rose-2-8-in-july-d0c1d0e7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17190 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17191: https://www.wsj.com/business/hospitality/chipotles-next-boss-has-one-job-dont-change-too-much-4f1af432
# ⚠️ Kein brauchbarer Inhalt – Artikel 17191 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17192: https://www.wsj.com/us-news/law/supreme-court-takes-mixed-approach-on-arizona-proof-of-citizenship-requirements-for-voting-1d1a091e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17192 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17193: https://www.wsj.com/opinion/democrats-freedom-tim-walz-dnc-kamala-harris-joe-biden-fdr-chicago-a41978be
# ⚠️ Kein brauchbarer Inhalt – Artikel 17193 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17194: https://www.wsj.com/opinion/electric-vehicles-ford-stellantis-biden-administration-subsidies-905ecfbb
# ⚠️ Kein brauchbarer Inhalt – Artikel 17194 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17195: https://www.wsj.com/opinion/kentucky-amendment-2-school-choice-charter-schools-vouchers-andy-beshear-2118413d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17195 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17196: https://www.wsj.com/opinion/israel-iran-u-s-force-pentagon-biden-administration-gaza-hamas-dcf393a1
# ⚠️ Kein brauchbarer Inhalt – Artikel 17196 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17197: https://www.wsj.com/arts-culture/film/the-crow-review-bill-skarsgard-fka-twigs-rupert-sanders-3fca0455
# ⚠️ Kein brauchbarer Inhalt – Artikel 17197 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17198: https://www.wsj.com/arts-culture/television/pachinko-season-2-review-the-game-of-life-on-apple-tv-d4c92f6a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17198 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17199: https://www.wsj.com/opinion/kennedy-and-shanahan-make-democrats-nervous-3692a1a7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17199 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17200: https://www.wsj.com/arts-culture/film/blink-twice-review-zoe-kravitz-channing-tatum-naomi-ackie-private-island-ba56fa55
# ⚠️ Kein brauchbarer Inhalt – Artikel 17200 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17201: https://www.wsj.com/world/americas/brazil-clamps-down-on-migrants-heading-to-the-u-s-a1a7dfc3
# ⚠️ Kein brauchbarer Inhalt – Artikel 17201 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17202: https://www.wsj.com/business/media/skydance-demands-that-paramount-stops-negotiating-with-bronfman-766f2e1f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17202 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17203: https://www.wsj.com/world/americas/venezuelas-supreme-court-backs-maduro-as-election-winner-93f5d184
# ⚠️ Kein brauchbarer Inhalt – Artikel 17203 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17204: https://www.wsj.com/style/fashion/demure-how-a-tik-tok-influencer-made-coyness-the-mode-of-the-moment-ace865ef
# ⚠️ Kein brauchbarer Inhalt – Artikel 17204 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17205: https://www.wsj.com/arts-culture/television/blake-edwards-a-love-story-in-24-frames-pbs-american-masters-53355f60
# ⚠️ Kein brauchbarer Inhalt – Artikel 17205 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17206: https://www.wsj.com/opinion/america-needs-a-china-strategy-biden-team-lacking-plan-after-ukraine-diverted-focus-a622932a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17206 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17207: https://www.wsj.com/opinion/kamala-harris-price-control-delusion-consumers-still-end-up-paying-2024-election-045fb8e6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17207 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17208: https://www.wsj.com/opinion/joy-to-the-world-kamalas-here-campaign-strategy-brand-politics-election-75eafe31
# ⚠️ Kein brauchbarer Inhalt – Artikel 17208 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17209: https://www.wsj.com/opinion/kamala-harris-the-dnc-speeches-and-democrats-joy-cc93a0f4
# ⚠️ Kein brauchbarer Inhalt – Artikel 17209 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17210: https://www.wsj.com/lifestyle/travel/on-a-trip-to-seoul-catching-glimpses-of-isolated-north-korea-0da866c0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17210 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17211: https://www.wsj.com/opinion/to-break-the-moral-spine-of-the-jews-anti-zionist-loyalty-oaths-progressive-culture-82d094f2
# ⚠️ Kein brauchbarer Inhalt – Artikel 17211 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17212: https://www.wsj.com/arts-culture/film/close-your-eyes-review-victor-erice-elegiac-epic-spirit-of-the-beehive-82190df0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17212 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17213: https://www.wsj.com/opinion/republicans-better-get-on-the-ball-thomas-sowell-2024-election-kamala-harris-91883df6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17213 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17214: https://www.wsj.com/articles/hidden-track-friday-crossword-august-23-f233566b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17214 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17215: https://www.wsj.com/real-estate/luxury-homes/this-oceanfront-home-sold-for-a-record-breaking-price-now-it-could-fetch-even-more-0427080c
# ⚠️ Kein brauchbarer Inhalt – Artikel 17215 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17216: https://www.wsj.com/us-news/law/partner-of-ex-ftx-executive-indicted-on-campaign-finance-offenses-4ae6a86a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17216 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17217: https://www.wsj.com/arts-culture/food-cooking/pilsners-crisp-summer-drink-fbdab821
# ⚠️ Kein brauchbarer Inhalt – Artikel 17217 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17218: https://www.wsj.com/finance/investing/never-enough-review-the-burden-of-billions-bfc469ac
# ⚠️ Kein brauchbarer Inhalt – Artikel 17218 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-23...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-23: max. 30 Article
# ➡️ Öffne Artikel 17284: https://www.wsj.com/style/fashion/i-wanted-a-polo-like-harrison-fordsfor-75-max-heres-what-i-found-5bf2c146
# ⚠️ Kein brauchbarer Inhalt – Artikel 17284 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17285: https://www.wsj.com/opinion/chuck-schumer-senate-filibuster-kamala-harris-democrats-8ded2e7e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17285 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17286: https://www.wsj.com/opinion/rfk-jr-endorses-donald-trump-2024-nicole-shanahan-kamala-harris-715235a1
# ⚠️ Kein brauchbarer Inhalt – Artikel 17286 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17287: https://www.wsj.com/opinion/biden-drug-prices-inflation-reduction-act-pharma-cms-generics-6be3a99a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17287 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17288: https://www.wsj.com/opinion/all-the-struggles-are-connected-protesters-fail-to-disrupt-dnc-but-get-message-across-d2254d6d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17288 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17289: https://www.wsj.com/opinion/why-is-new-york-paying-so-much-for-wind-power-generate-electricity-costs-d482c79b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17289 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17290: https://www.wsj.com/articles/air-canada-pilots-step-up-pressure-on-carrier-as-strike-threat-looms-2a3ce5f6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17290 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17291: https://www.wsj.com/opinion/the-art-of-the-presidential-sale-2024-election-campaign-spin-dnc-rnc-a4ecabb0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17291 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17292: https://www.wsj.com/opinion/follow-the-science-biden-climate-policy-is-a-fraud-new-study-green-subsidy-no-impact-06fd5c00
# ⚠️ Kein brauchbarer Inhalt – Artikel 17292 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17293: https://www.wsj.com/opinion/another-student-loan-boondoggle-harris-biden-debt-taxpayers-2cfcecfb
# ⚠️ Kein brauchbarer Inhalt – Artikel 17293 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17294: https://www.wsj.com/opinion/notable-quotable-no-more-neoliberalism-democratic-party-changes-c74423e7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17294 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17295: https://www.wsj.com/arts-culture/fine-art/liberty-leading-the-people-restoration-of-a-rousing-symbol-6a3247ee
# ⚠️ Kein brauchbarer Inhalt – Artikel 17295 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17296: https://www.wsj.com/arts-culture/books/15-books-we-read-this-week-722501c9
# ⚠️ Kein brauchbarer Inhalt – Artikel 17296 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17297: https://www.wsj.com/health/healthcare/j-j-takes-aim-at-hospital-drug-discount-program-d17c5a7a
# ⚠️ Kein brauchbarer Inhalt – Artikel 17297 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17298: https://www.wsj.com/articles/u-s-unveils-more-sanctions-targeting-russias-supply-chains-87429139
# ⚠️ Kein brauchbarer Inhalt – Artikel 17298 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17299: https://www.wsj.com/economy/central-banking/powell-issues-strongest-signal-yet-that-rate-cuts-are-on-the-way-62952bd6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17299 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17300: https://www.wsj.com/articles/i-hesitate-to-add-saturday-crossword-august-24-bf17a882
# ⚠️ Kein brauchbarer Inhalt – Artikel 17300 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17301: https://www.wsj.com/articles/treasure-heist-saturday-cryptic-puzzle-august-24-e1de9135
# ⚠️ Kein brauchbarer Inhalt – Artikel 17301 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17302: https://www.wsj.com/articles/podcasts-used-to-be-ad-light-oases-not-anymore-ac698aec
# ⚠️ Kein brauchbarer Inhalt – Artikel 17302 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17303: https://www.wsj.com/world/russia/russian-authorities-kill-islamist-militants-after-prison-uprising-4d3a1d45
# ⚠️ Kein brauchbarer Inhalt – Artikel 17303 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17304: https://www.wsj.com/articles/teamsters-to-contest-end-of-work-stoppage-at-canadian-pacific-kansas-city-755592a5
# ⚠️ Kein brauchbarer Inhalt – Artikel 17304 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17305: https://www.wsj.com/world/americas/venezuelas-maduro-intensifies-repression-b673f33d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17305 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17306: https://www.wsj.com/real-estate/luxury-homes/they-spent-27-million-building-their-dream-house-now-its-hitting-the-auction-block-0e93c36e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17306 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17307: https://www.wsj.com/arts-culture/food-cooking/why-italian-cookies-are-the-breakfast-power-move-cfe69036
# ⚠️ Kein brauchbarer Inhalt – Artikel 17307 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17308: https://www.wsj.com/us-news/law/u-s-accuses-real-estate-software-company-of-illegally-coordinating-rent-prices-26e5c71d
# ...
#
# ➡️ Öffne Artikel 17421: https://www.wsj.com/sports/baseball/danny-jansen-red-sox-blue-jays-e80c0798
# ⚠️ Kein brauchbarer Inhalt – Artikel 17421 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17422: https://www.wsj.com/world/asia/in-beijings-quest-for-control-of-the-south-china-sea-a-new-flashpoint-emerges-5ac29fc5
# ⚠️ Kein brauchbarer Inhalt – Artikel 17422 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17423: https://www.wsj.com/opinion/in-defense-of-president-bidens-time-in-office-edcbbdc9
# ⚠️ Kein brauchbarer Inhalt – Artikel 17423 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17424: https://www.wsj.com/opinion/oregon-preview-of-healthcare-policy-under-harris-7521644c
# ⚠️ Kein brauchbarer Inhalt – Artikel 17424 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17425: https://www.wsj.com/opinion/what-will-happen-to-hospital-at-home-care-1862355d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17425 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17426: https://www.wsj.com/opinion/china-rare-earth-minerals-are-the-ace-up-beijings-sleeve-14a75027
# ⚠️ Kein brauchbarer Inhalt – Artikel 17426 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17427: https://www.wsj.com/opinion/californians-texas-colorado-migration-politics-138b8d00
# ⚠️ Kein brauchbarer Inhalt – Artikel 17427 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17428: https://www.wsj.com/opinion/regime-change-gone-wrong-jimmy-carter-iran-10edabe7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17428 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17429: https://www.wsj.com/us-news/climate-environment/energy-efficient-appliances-quiz-0e3082e5
# ⚠️ Kein brauchbarer Inhalt – Artikel 17429 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17430: https://www.wsj.com/finance/currencies/tether-cryptocurrency-ai-business-394271db
# ⚠️ Kein brauchbarer Inhalt – Artikel 17430 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17431: https://www.wsj.com/finance/this-soccer-clubs-american-owners-are-either-geniuses-or-fools-74701bda
# ⚠️ Kein brauchbarer Inhalt – Artikel 17431 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17432: https://www.wsj.com/lifestyle/cars/her-volkswagens-journey-involves-lucky-numbers-and-a-celebritys-lipstick-72a00e3b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17432 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17433: https://www.wsj.com/sports/tennis/jannik-sinner-doping-ban-us-open-c2811abf
# ⚠️ Kein brauchbarer Inhalt – Artikel 17433 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17434: https://www.wsj.com/us-news/climate-environment/kyle-texas-city-growth-heat-water-6660dc42
# ⚠️ Kein brauchbarer Inhalt – Artikel 17434 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-26...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-26: max. 30 Article
# ➡️ Öffne Artikel 17446: https://www.wsj.com/business/c-suite/apple-names-kevan-parekh-its-next-chief-financial-officer-4fb0520e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17446 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17447: https://www.wsj.com/opinion/kafka-and-social-media-a-bug-not-a-feature-metamorphosis-85f11cfd
# ⚠️ Kein brauchbarer Inhalt – Artikel 17447 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17448: https://www.wsj.com/opinion/kamala-harris-afghanistan-withdrawal-joe-biden-kenneth-mckenzie-05d9e69b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17448 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17449: https://www.wsj.com/opinion/united-teachers-of-dade-election-miami-dade-education-coalition-union-ron-desantis-5637e1c9
# ⚠️ Kein brauchbarer Inhalt – Artikel 17449 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17450: https://www.wsj.com/opinion/north-carolina-early-voting-sept-6-kamala-harris-donald-trump-bdfab522
# ⚠️ Kein brauchbarer Inhalt – Artikel 17450 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17451: https://www.wsj.com/opinion/netanyahus-place-in-history-israel-prime-minister-politics-3efed8aa
# ⚠️ Kein brauchbarer Inhalt – Artikel 17451 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17452: https://www.wsj.com/opinion/junk-science-sometimes-still-prevails-in-court-pharma-legal-system-a25ca1c0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17452 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17453: https://www.wsj.com/opinion/the-legally-dubious-campaign-against-kentucky-school-choice-7e69e48b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17453 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17454: https://www.wsj.com/opinion/notable-quotable-climate-change-voters-election-policy-e93f7fdf
# ⚠️ Kein brauchbarer Inhalt – Artikel 17454 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17455: https://www.wsj.com/opinion/confessions-of-a-pro-lifer-election-policy-politics-culture-d304bbc7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17455 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17456: https://www.wsj.com/opinion/democrats-win-some-lose-some-trying-to-kick-rivals-off-ballots-58ec84a3
# ⚠️ Kein brauchbarer Inhalt – Artikel 17456 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17457: https://www.wsj.com/us-news/law/kroger-and-albertsons-defend-merger-with-food-prices-in-political-crosshairs-3b57da33
# ⚠️ Kein brauchbarer Inhalt – Artikel 17457 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17458: https://www.wsj.com/sports/tennis/coco-gauff-forehand-us-open-be6ec088
# ⚠️ Kein brauchbarer Inhalt – Artikel 17458 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17459: https://www.wsj.com/opinion/the-bad-economic-idea-that-will-never-die-b5e3c49e
# ⚠️ Kein brauchbarer Inhalt – Artikel 17459 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17460: https://www.wsj.com/opinion/viktor-orban-hungary-china-russia-west-30a91785
# ⚠️ Kein brauchbarer Inhalt – Artikel 17460 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17461: https://www.wsj.com/opinion/chicago-rage-against-the-machine-politics-not-progressives-b1d6ebe9
# ⚠️ Kein brauchbarer Inhalt – Artikel 17461 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17462: https://www.wsj.com/opinion/the-circle-of-political-life-biden-harris-a24aa6c7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17462 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17463: https://www.wsj.com/arts-culture/fine-art/collecting-inspiration-edward-c-moore-at-tiffany-co-review-shining-craftsmanship-5743abb4
# ⚠️ Kein brauchbarer Inhalt – Artikel 17463 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17464: https://www.wsj.com/opinion/no-tax-on-tips-try-again-5c5d0531
# ⚠️ Kein brauchbarer Inhalt – Artikel 17464 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17465: https://www.wsj.com/politics/elections/campaign-lays-bare-debate-over-what-it-means-to-be-a-real-american-815bf205
# ⚠️ Kein brauchbarer Inhalt – Artikel 17465 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17466: https://www.wsj.com/world/europe/macron-fires-back-at-critics-of-telegram-ceo-detention-1011fcd7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17466 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17467: https://www.wsj.com/articles/hold-your-applause-tuesday-crossword-august-27-04c1f250
# ⚠️ Kein brauchbarer Inhalt – Artikel 17467 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17468: https://www.wsj.com/tech/ai/apple-sends-invites-for-sept-9-event-new-iphone-and-ai-features-expected-f97b0816
# ⚠️ Kein brauchbarer Inhalt – Artikel 17468 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17469: https://www.wsj.com/opinion/starbucks-new-ceo-has-a-big-footprint-commutes-private-jet-nevermind-climate-goals-3df1aa5f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17469 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17470: https://www.wsj.com/opinion/democrats-deception-may-be-enough-to-win-again-dnc-kamala-harris-election-8572df67
# ⚠️ Kein brauchbarer Inhalt – Artikel 17470 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17471: https://www.wsj.com/real-estate/luxury-homes/joshua-kushner-karlie-kloss-wave-house-malibu-e760c07f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17471 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17472: https://www.wsj.com/economy/jobs/canada-to-tighten-temporary-foreign-worker-program-as-unemployment-rises-34cba4c8
# ⚠️ Kein brauchbarer Inhalt – Artikel 17472 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17473: https://www.wsj.com/world/middle-east/after-hezbollahs-retaliation-all-eyes-fix-on-iran-329baa18
# ⚠️ Kein brauchbarer Inhalt – Artikel 17473 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17474: https://www.wsj.com/real-estate/commercial/ken-griffin-reveals-plans-for-citadels-miami-headquarters-06b4aba6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17474 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17475: https://www.wsj.com/arts-culture/books/empires-son-empires-orphan-review-imperial-fantasies-12024c57
# ⚠️ Kein brauchbarer Inhalt – Artikel 17475 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-27...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-27: max. 30 Article
# ➡️ Öffne Artikel 17506: https://www.wsj.com/business/earnings/fortescue-annual-net-profit-rises-18-1add6b3b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17506 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17507: https://www.wsj.com/articles/totalenergies-unit-to-pay-48-million-over-alleged-gasoline-futures-manipulation-9119c9e1
# ⚠️ Kein brauchbarer Inhalt – Artikel 17507 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17508: https://www.wsj.com/us-news/law/jack-smith-trump-indictment-january-6-case-51793bb0
# ⚠️ Kein brauchbarer Inhalt – Artikel 17508 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17509: https://www.wsj.com/business/media/trump-finds-a-new-media-foe-in-abc-news-as-debate-drama-mounts-e15f9310
# ⚠️ Kein brauchbarer Inhalt – Artikel 17509 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17510: https://www.wsj.com/opinion/the-harris-walz-youth-vote-democratic-ticket-election-2024-5ecca995
# ⚠️ Kein brauchbarer Inhalt – Artikel 17510 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17511: https://www.wsj.com/opinion/telegram-pavel-durov-arrest-france-europe-speech-elon-musk-thierry-breton-5a3fa9cd
# ⚠️ Kein brauchbarer Inhalt – Artikel 17511 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17512: https://www.wsj.com/opinion/massachusetts-taxes-bill-belichick-new-england-patriots-bd13270c
# ⚠️ Kein brauchbarer Inhalt – Artikel 17512 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17513: https://www.wsj.com/opinion/colorado-property-tax-cut-jared-polis-tabor-republicans-3d365ba6
# ⚠️ Kein brauchbarer Inhalt – Artikel 17513 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17514: https://www.wsj.com/opinion/democrats-jump-for-joy-but-could-head-back-to-earth-election-debates-interviews-record-d4baf76f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17514 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17515: https://www.wsj.com/opinion/notable-quotable-football-sports-politics-election-symbolism-democrats-6f8b11cb
# ⚠️ Kein brauchbarer Inhalt – Artikel 17515 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17516: https://www.wsj.com/opinion/abortion-may-not-be-a-winner-for-democrats-this-fall-harris-walz-campaign-b715082b
# ⚠️ Kein brauchbarer Inhalt – Artikel 17516 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17517: https://www.wsj.com/arts-culture/music/short-n-sweet-review-sabrina-carpenters-pop-confections-1a57aa83
# ⚠️ Kein brauchbarer Inhalt – Artikel 17517 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17518: https://www.wsj.com/arts-culture/television/odysseus-returns-review-unearthing-myths-on-pbs-7b93c12f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17518 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17519: https://www.wsj.com/articles/nordea-to-pay-35-million-for-anti-money-laundering-violations-0916fddd
# ⚠️ Kein brauchbarer Inhalt – Artikel 17519 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17520: https://www.wsj.com/articles/boy-scouts-to-auction-norman-rockwell-paintings-other-art-to-fund-sex-abuse-settlement-b97441fd
# ⚠️ Kein brauchbarer Inhalt – Artikel 17520 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17521: https://www.wsj.com/sports/football/nfl-private-equity-rules-owners-meeting-vote-222887b7
# ⚠️ Kein brauchbarer Inhalt – Artikel 17521 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17522: https://www.wsj.com/opinion/the-tell-in-zuckerbergs-letter-to-congress-law-politics-censorship-pressure-meta-facebook-5de24612
# ⚠️ Kein brauchbarer Inhalt – Artikel 17522 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17523: https://www.wsj.com/opinion/trump-vs-kamalas-coronation-election-russia-media-efb43192
# ⚠️ Kein brauchbarer Inhalt – Artikel 17523 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17524: https://www.wsj.com/finance/banking/warren-buffet-bank-of-america-stock-6d8ea95d
# ⚠️ Kein brauchbarer Inhalt – Artikel 17524 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17525: https://www.wsj.com/arts-culture/music/oasis-reunion-tour-liam-noel-gallagher-26d2be69
# ⚠️ Kein brauchbarer Inhalt – Artikel 17525 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17526: https://www.wsj.com/articles/hot-potatoes-wednesday-crossword-august-28-636bbfac
# ⚠️ Kein brauchbarer Inhalt – Artikel 17526 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17527: https://www.wsj.com/world/ukraine-deploys-f-16s-against-massive-russian-barrage-but-says-it-doesnt-have-enough-of-them-7781b133
# ⚠️ Kein brauchbarer Inhalt – Artikel 17527 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17528: https://www.wsj.com/articles/omnicom-brings-tbwa-bbdo-and-other-agencies-under-same-leadership-851a7fa5
# ⚠️ Kein brauchbarer Inhalt – Artikel 17528 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17529: https://www.wsj.com/opinion/biden-harris-administration-no-remorse-for-free-speech-abuses-56113cc2
# ⚠️ Kein brauchbarer Inhalt – Artikel 17529 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17530: https://www.wsj.com/world/middle-east/israeli-military-frees-hostage-in-rescue-mission-8c851a3f
# ⚠️ Kein brauchbarer Inhalt – Artikel 17530 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17531: https://www.wsj.com/business/entrepreneurship/leonard-riggio-who-built-barnes-noble-into-book-retailing-powerhouse-is-dead-at-83-43a02c13
# ⚠️ Kein brauchbarer Inhalt – Artikel 17531 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17532: https://www.wsj.com/arts-culture/food-cooking/an-irresistible-way-to-celebrate-peak-tomato-season-this-easy-recipe-7af6bc21
# ⚠️ Kein brauchbarer Inhalt – Artikel 17532 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17533: https://www.wsj.com/arts-culture/books/the-strategists-review-the-men-who-made-the-war-5f8ffc25
# ⚠️ Kein brauchbarer Inhalt – Artikel 17533 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17534: https://www.wsj.com/articles/fed-rate-cuts-are-coming-but-investors-disagree-on-the-path-forward-648e2864
# ⚠️ Kein brauchbarer Inhalt – Artikel 17534 wird übersprungen.
# ✅ Artikel gespeichert
#
# ➡️ Öffne Artikel 17535: https://www.wsj.com/politics/policy/kamala-harris-tax-plan-2024-election-10f95d18
# ⚠️ Kein brauchbarer Inhalt – Artikel 17535 wird übersprungen.
# ✅ Artikel gespeichert
#
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-08-31...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-08-31: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🔍 Überprüfe 2024-09-01...
# 🚀 Lade fehlende Artikel...
#
# 📆 2024-09-01: max. 30 Article
# ⚠️ Keine ungescannten Artikel für diesen Tag.
# ✅ Fertig mit diesem Tag.
#
# 🏁 Alle angegebenen Tage wurden überprüft.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# DB path
DB_PATH = r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"

# Connect to DB
conn = sqlite3.connect(DB_PATH)

# 🧠 Step 1: Tage mit weniger als 30 Artikeln (Problemtage)
query_problem_days = """
SELECT ai.year, ai.month, ai.day,
       COUNT(DISTINCT a.article_id) as article_count
FROM articles_index ai
LEFT JOIN article a ON ai.id = a.index_id
    AND a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
GROUP BY ai.year, ai.month, ai.day
HAVING article_count < 30
"""

df_problems = pd.read_sql_query(query_problem_days, conn)

# 🧠 Step 2: Zähle, wie viele Links es für diese Tage gibt
query_links = """
SELECT year, month, day, COUNT(*) as num_links
FROM articles_index
GROUP BY year, month, day
"""

df_links = pd.read_sql_query(query_links, conn)
conn.close()

# 🧠 Step 3: Join beide DataFrames auf (year, month, day)
df_merged = pd.merge(
    df_problems[['year', 'month', 'day']],
    df_links,
    on=['year', 'month', 'day'],
    how='left'
)

# Erzeuge Datums-Spalte
df_merged['date'] = pd.to_datetime(
    df_merged['year'].astype(str) + '-' +
    df_merged['month'].astype(str).str.zfill(2) + '-' +
    df_merged['day'].astype(str).str.zfill(2)
)

# Show all rows
pd.set_option('display.max_rows', None)  # zeigt alle Zeilen an

# Ergebnis anzeigen
print("📅 Link count for problematic days (article_count < 30):")
print(df_merged[['date', 'num_links']])
# Out:
# 📅 Link count for problematic days (article_count < 30):
#          date  num_links
# 0  2024-01-14         25
# 1  2024-10-12         29
# 2  2024-10-19         23
# 3  2024-10-26         28
# 4  2024-10-05         26
# 5  2024-11-16         25
# 6  2024-11-23         24
# 7  2024-11-30         25
# 8  2024-11-09         26
# 9  2024-12-14         21
# 10 2024-12-21         21
# 11 2024-12-28         18
# 12 2024-12-07         29
# 13 2024-02-17         26
# 14 2024-02-18         26
# 15 2024-02-24         25
# 16 2024-03-02         29
# 17 2024-03-30         28
# 18 2024-04-27         27
# 19 2024-05-18         26
# 20 2024-05-25         25
# 21 2024-05-26         20
# 22 2024-05-04         29
# 23 2024-06-01         28
# 24 2024-06-15         24
# 25 2024-06-22         28
# 26 2024-06-29         28
# 27 2024-07-20         27
# 28 2024-07-06         25
# 29 2024-08-18         42
# 30 2024-08-19         63
# 31 2024-08-02        102
# 32 2024-08-20         70
# 33 2024-08-21         85
# 34 2024-08-22         95
# 35 2024-08-23         92
# 36 2024-08-24         29
# 37 2024-08-25         41
# 38 2024-08-26         60
# 39 2024-08-27         70
# 40 2024-08-31         28
# 41 2024-09-01         27

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# DB path
DB_PATH = r"C:\Users\PC\Desktop\Masterarbeit\Code\articlesWSJ.db"

# Connect to DB
conn = sqlite3.connect(DB_PATH)

# 🧠 Step 1: Tage mit weniger als 30 Artikeln (Problemtage)
query_problem_days = """
SELECT ai.year, ai.month, ai.day,
       COUNT(DISTINCT a.article_id) as article_count
FROM articles_index ai
LEFT JOIN article a ON ai.id = a.index_id
    AND a.corpus IS NOT NULL AND a.corpus != '' AND a.corpus != 'not found'
GROUP BY ai.year, ai.month, ai.day
HAVING article_count < 30
"""

df_problems = pd.read_sql_query(query_problem_days, conn)

# 🧠 Step 2: Zähle, wie viele Links es für diese Tage gibt
query_links = """
SELECT year, month, day, COUNT(*) as num_links
FROM articles_index
GROUP BY year, month, day
"""

df_links = pd.read_sql_query(query_links, conn)
conn.close()

# 🧠 Step 3: Join beide DataFrames auf (year, month, day)
df_merged = pd.merge(
    df_problems[['year', 'month', 'day']],
    df_links,
    on=['year', 'month', 'day'],
    how='left'
)

# Erzeuge Datums-Spalte
df_merged['date'] = pd.to_datetime(
    df_merged['year'].astype(str) + '-' +
    df_merged['month'].astype(str).str.zfill(2) + '-' +
    df_merged['day'].astype(str).str.zfill(2)
)

# Show all rows
pd.set_option('display.max_rows', None)  # zeigt alle Zeilen an

# Ergebnis anzeigen
print("📅 Link count for problematic days (article_count < 30):")
print(df_merged[['date', 'num_links']])



def reset_failed_articles(days, db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    for year, month, day in days:
        year, month, day = int(year), int(month), int(day)
        print(f"♻️ Resetting failed articles for {year}-{month:02d}-{day:02d}...")
            # Lösche Artikel ohne Inhalt
        cursor.execute("""
            DELETE FROM article
            WHERE index_id IN (
                SELECT id FROM articles_index
                WHERE year = ? AND month = ? AND day = ?
            )
            AND (corpus IS NULL OR corpus = '' OR corpus = 'not found')
        """, (year, month, day))

        # Setze scanned_status auf 0 für diese IDs
        cursor.execute("""
            UPDATE articles_index
            SET scanned_status = 0
            WHERE year = ? AND month = ? AND day = ?
            AND id NOT IN (
                SELECT index_id FROM article
            )
        """, (year, month, day))

    conn.commit()
    conn.close()
    print("✅ Reset completed.")

reset_failed_articles(
    list(df_merged[['year', 'month', 'day']].itertuples(index=False, name=None)),
    DB_PATH
)
# Out:
# 📅 Link count for problematic days (article_count < 30):
#          date  num_links
# 0  2024-01-14         25
# 1  2024-10-12         29
# 2  2024-10-19         23
# 3  2024-10-26         28
# 4  2024-10-05         26
# 5  2024-11-16         25
# 6  2024-11-23         24
# 7  2024-11-30         25
# 8  2024-11-09         26
# 9  2024-12-14         21
# 10 2024-12-21         21
# 11 2024-12-28         18
# 12 2024-12-07         29
# 13 2024-02-17         26
# 14 2024-02-18         26
# 15 2024-02-20         80
# 16 2024-02-21         87
# 17 2024-02-24         25
# 18 2024-03-16         30
# 19 2024-03-17         43
# 20 2024-03-18         87
# 21 2024-03-19         83
# 22 2024-03-02         29
# 23 2024-03-20         96
# 24 2024-03-21        106
# 25 2024-03-22        103
# 26 2024-03-23         35
# 27 2024-03-24         47
# 28 2024-03-25         77
# 29 2024-03-26         93
# 30 2024-03-27        102
# 31 2024-03-28         99
# 32 2024-03-29         89
# 33 2024-03-03         52
# 34 2024-03-30         28
# 35 2024-03-31         43
# 36 2024-03-04         76
# 37 2024-03-05         85
# 38 2024-03-06         96
# 39 2024-03-07        102
# 40 2024-03-08        103
# 41 2024-03-09         32
# 42 2024-04-01         76
# 43 2024-04-27         27
# 44 2024-05-18         26
# 45 2024-05-22         88
# 46 2024-05-25         25
# 47 2024-05-26         20
# 48 2024-05-04         29
# 49 2024-06-01         28
# 50 2024-06-15         24
# 51 2024-06-22         28
# 52 2024-06-29         28
# 53 2024-07-20         27
# 54 2024-07-28         40
# 55 2024-07-29         75
# 56 2024-07-03         67
# 57 2024-07-30         82
# 58 2024-07-31         88
# 59 2024-07-04         59
# 60 2024-07-05         88
# 61 2024-07-06         25
# 62 2024-07-07         37
# 63 2024-07-08         76
# 64 2024-07-09         66
# 65 2024-08-01        104
# 66 2024-08-10         39
# 67 2024-08-11         43
# 68 2024-08-12         58
# 69 2024-08-13         79
# 70 2024-08-14         84
# 71 2024-08-15         93
# 72 2024-08-16         84
# 73 2024-08-17         32
# 74 2024-08-18         42
# 75 2024-08-19         63
# 76 2024-08-02        102
# 77 2024-08-20         70
# 78 2024-08-21         85
# 79 2024-08-22         95
# 80 2024-08-23         92
# 81 2024-08-24         29
# 82 2024-08-25         41
# 83 2024-08-26         60
# 84 2024-08-27         70
# 85 2024-08-31         28
# 86 2024-09-01         27
# ♻️ Resetting failed articles for 2024-01-14...
# ♻️ Resetting failed articles for 2024-10-12...
# ♻️ Resetting failed articles for 2024-10-19...
# ♻️ Resetting failed articles for 2024-10-26...
# ♻️ Resetting failed articles for 2024-10-05...
# ♻️ Resetting failed articles for 2024-11-16...
# ♻️ Resetting failed articles for 2024-11-23...
# ♻️ Resetting failed articles for 2024-11-30...
# ♻️ Resetting failed articles for 2024-11-09...
# ♻️ Resetting failed articles for 2024-12-14...
# ♻️ Resetting failed articles for 2024-12-21...
# ♻️ Resetting failed articles for 2024-12-28...
# ♻️ Resetting failed articles for 2024-12-07...
# ♻️ Resetting failed articles for 2024-02-17...
# ♻️ Resetting failed articles for 2024-02-18...
# ♻️ Resetting failed articles for 2024-02-20...
# ♻️ Resetting failed articles for 2024-02-21...
# ♻️ Resetting failed articles for 2024-02-24...
# ♻️ Resetting failed articles for 2024-03-16...
# ♻️ Resetting failed articles for 2024-03-17...
# ♻️ Resetting failed articles for 2024-03-18...
# ♻️ Resetting failed articles for 2024-03-19...
# ♻️ Resetting failed articles for 2024-03-02...
# ♻️ Resetting failed articles for 2024-03-20...
# ♻️ Resetting failed articles for 2024-03-21...
# ♻️ Resetting failed articles for 2024-03-22...
# ♻️ Resetting failed articles for 2024-03-23...
# ♻️ Resetting failed articles for 2024-03-24...
# ♻️ Resetting failed articles for 2024-03-25...
# ♻️ Resetting failed articles for 2024-03-26...
# ♻️ Resetting failed articles for 2024-03-27...
# ♻️ Resetting failed articles for 2024-03-28...
# ♻️ Resetting failed articles for 2024-03-29...
# ♻️ Resetting failed articles for 2024-03-03...
# ♻️ Resetting failed articles for 2024-03-30...
# ♻️ Resetting failed articles for 2024-03-31...
# ♻️ Resetting failed articles for 2024-03-04...
# ♻️ Resetting failed articles for 2024-03-05...
# ♻️ Resetting failed articles for 2024-03-06...
# ♻️ Resetting failed articles for 2024-03-07...
# ♻️ Resetting failed articles for 2024-03-08...
# ♻️ Resetting failed articles for 2024-03-09...
# ♻️ Resetting failed articles for 2024-04-01...
# ♻️ Resetting failed articles for 2024-04-27...
# ♻️ Resetting failed articles for 2024-05-18...
# ♻️ Resetting failed articles for 2024-05-22...
# ♻️ Resetting failed articles for 2024-05-25...
# ♻️ Resetting failed articles for 2024-05-26...
# ♻️ Resetting failed articles for 2024-05-04...
# ♻️ Resetting failed articles for 2024-06-01...
# ♻️ Resetting failed articles for 2024-06-15...
# ♻️ Resetting failed articles for 2024-06-22...
# ♻️ Resetting failed articles for 2024-06-29...
# ♻️ Resetting failed articles for 2024-07-20...
# ♻️ Resetting failed articles for 2024-07-28...
# ♻️ Resetting failed articles for 2024-07-29...
# ♻️ Resetting failed articles for 2024-07-03...
# ♻️ Resetting failed articles for 2024-07-30...
# ♻️ Resetting failed articles for 2024-07-31...
# ♻️ Resetting failed articles for 2024-07-04...
# ♻️ Resetting failed articles for 2024-07-05...
# ♻️ Resetting failed articles for 2024-07-06...
# ♻️ Resetting failed articles for 2024-07-07...
# ♻️ Resetting failed articles for 2024-07-08...
# ♻️ Resetting failed articles for 2024-07-09...
# ♻️ Resetting failed articles for 2024-08-01...
# ♻️ Resetting failed articles for 2024-08-10...
# ♻️ Resetting failed articles for 2024-08-11...
# ♻️ Resetting failed articles for 2024-08-12...
# ♻️ Resetting failed articles for 2024-08-13...
# ♻️ Resetting failed articles for 2024-08-14...
# ♻️ Resetting failed articles for 2024-08-15...
# ♻️ Resetting failed articles for 2024-08-16...
# ♻️ Resetting failed articles for 2024-08-17...
# ♻️ Resetting failed articles for 2024-08-18...
# ♻️ Resetting failed articles for 2024-08-19...
# ♻️ Resetting failed articles for 2024-08-02...
# ♻️ Resetting failed articles for 2024-08-20...
# ♻️ Resetting failed articles for 2024-08-21...
# ♻️ Resetting failed articles for 2024-08-22...
# ♻️ Resetting failed articles for 2024-08-23...
# ♻️ Resetting failed articles for 2024-08-24...
# ♻️ Resetting failed articles for 2024-08-25...
# ♻️ Resetting failed articles for 2024-08-26...
# ♻️ Resetting failed articles for 2024-08-27...
# ♻️ Resetting failed articles for 2024-08-31...
# ♻️ Resetting failed articles for 2024-09-01...
# ✅ Reset completed.
